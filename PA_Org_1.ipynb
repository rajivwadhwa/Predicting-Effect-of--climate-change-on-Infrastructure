# %%
import numpy as np
import pandas as pd
import os
import seaborn as sb
import matplotlib.pyplot as plt

# %%
os.chdir('C:\\Users\\rwadhwa31\\OneDrive - Georgia Institute of Technology\\Fall 2021\\DACEE - 8813\\Final Project')

# %%
climate_df = pd.read_excel('work.xlsx','Climate-Final(1964-2012)',parse_dates = {'timedate': ['YEAR','MONTH']}, index_col='timedate')
climate_df
# Out:
#            SHRP_ID  VWS_ID  TOTAL_MON_PRECIP  TOTAL_SNOWFALL_MONTH  \
# timedate
# 1964-01-01    0601  470600         95.199997                  24.0
# 1964-02-01    0601  470600         85.800003                  50.0
# 1964-03-01    0601  470600        179.300003                   0.0
# 1964-04-01    0601  470600        223.300003                   0.0
# 1964-05-01    0601  470600         89.400002                   0.0
# ...            ...     ...               ...                   ...
# 2012-08-01    C350  471023         50.299999                   NaN
# 2012-09-01    C350  471023        217.899994                   NaN
# 2012-10-01    C350  471023         56.200001                   NaN
# 2012-11-01    C350  471023         27.100000                   NaN
# 2012-12-01    C350  471023        156.100006                   0.0
#
#             INTENSE_PRECIP_DAYS_MONTH  WET_DAYS_MONTH  NUM_MON_PRECIP_DAYS
# timedate
# 1964-01-01                          2              14                   31
# 1964-02-01                          2              16                   29
# 1964-03-01                          4              17                   31
# 1964-04-01                          5              17                   30
# 1964-05-01                          2               9                   31
# ...                               ...             ...                  ...
# 2012-08-01                          1               9                   31
# 2012-09-01                          3               8                   30
# 2012-10-01                          1              15                   31
# 2012-11-01                          0               5                   30
# 2012-12-01                          4              15                   31
#
# [20073 rows x 7 columns]

# %%
def dataframe_open(name):
    name_df = pd.read_excel('work.xlsx',name)
    return name_df

# %%
def grab_decade(start_yr, y_c_data, interval=10):
    '''Return years and counts for only a specific interval length.'''
    end_yr = int(start_yr) + interval - 1
    years = y_c_data[(y_c_data['YEAR'] <= end_yr) & (y_c_data['YEAR'] >= start_yr)]
    return years

# %%
# START RESAMPLING

climate_df2 = climate_df.resample('Y').mean()
climate_df2
# Out:
#                    VWS_ID  TOTAL_MON_PRECIP  TOTAL_SNOWFALL_MONTH  \
# timedate
# 1964-12-31  470728.000000        128.940152              6.227273
# 1965-12-31  470834.083333         96.551388             23.006944
# 1966-12-31  470834.083333         95.468749             33.506944
# 1967-12-31  470834.083333        101.755555              6.784722
# 1968-12-31  470834.083333         99.413889             48.243056
# 1969-12-31  470834.083333         92.950696             15.256944
# 1970-12-31  471744.777778        112.746296             15.509259
# 1971-12-31  472533.494949        102.075421             25.804714
# 1972-12-31  472469.571429        137.026429              5.909308
# 1973-12-31  472469.571429        146.660952             12.557143
# 1974-12-31  472469.571429        135.810476              3.864286
# 1975-12-31  472469.571429        134.985477              9.238095
# 1976-12-31  472469.571429        102.217380             11.973810
# 1977-12-31  472487.333333        119.394445             19.351852
# 1978-12-31  472447.891892        107.962613             37.691441
# 1979-12-31  472447.891892        144.907658             38.777027
# 1980-12-31  472410.552632         97.692544             19.980263
# 1981-12-31  472410.552632        100.230921              6.960526
# 1982-12-31  472410.552632        118.901316             15.605263
# 1983-12-31  472410.552632        117.316448              5.692982
# 1984-12-31  472410.552632        119.013377             11.195175
# 1985-12-31  472410.552632         90.017544             34.824561
# 1986-12-31  472410.552632        101.293201              7.269737
# 1987-12-31  472410.552632         93.977631             14.730263
# 1988-12-31  472410.552632        100.586403             24.958333
# 1989-12-31  472410.552632        138.576974              9.313596
# 1990-12-31  472410.552632        129.552851              1.149123
# 2003-12-31                   3.265351       14.760965            30.416667
# 2004-12-31                   3.026316       14.916667            30.500000
# 2005-12-31                   2.456140       12.780702            30.416667
# 2006-12-31                   2.822368       13.271930            30.416667
# 2007-12-31                   2.171053       11.063596            30.416667
# 2008-12-31                   2.642544       12.638158            30.500000
# 2009-12-31                   3.745614       14.432018            30.416667
# 2010-12-31                   2.982456       12.804825            30.416667
# 2011-12-31                   3.655702       12.467105            30.394737
# 2012-12-31                   2.594298       12.114035            30.500000
# 2013-12-31                   3.729167       14.812500            30.416667
# 2014-12-31                   3.000000       13.687500            30.416667
# 2015-12-31                   3.562500       13.604167            30.416667
# 2016-12-31                   2.625000       12.625000            30.500000
# 2017-12-31                   2.770833       13.916667            30.416667

# %%
longitudinal_iri_df = pd.read_excel('work.xlsx','Performance-Longitudinal(IRI)', index_col='VISIT_DATE', parse_dates = True)
iri_df = longitudinal_iri_df.drop(['STATE_CODE', 'STATE_CODE_EXP','RUN_NUMBER'], axis =1)    
iri_df2 = iri_df.resample('Y').mean()
iri_df2
# Out:
#             IRI_LEFT_WHEEL_PATH  IRI_RIGHT_WHEEL_PATH       MRI
# VISIT_DATE
# 1990-12-31             1.159741              1.232474  1.196044
# 1991-12-31             1.288453              1.346240  1.317347
# 1992-12-31             1.235933              1.334200  1.285059
# 1993-12-31                  NaN                   NaN       NaN
# 1994-12-31             1.246010              1.195067  1.220571
# 1995-12-31             1.366621              1.569759  1.468034
# 1996-12-31             1.308478              1.565870  1.437200
# 1997-12-31             0.774926              0.859852  0.817352
# 1998-12-31             0.884200              1.001300  0.942800
# 1999-12-31             1.031945              1.090191  1.061064
# 2000-12-31             1.609200              0.864200  1.236600
# 2001-12-31             0.921687              1.039162  0.980375
# 2002-12-31             1.005811              1.208356  1.107011
# 2003-12-31             0.988662              1.037046  1.012862
# 2004-12-31             1.014558              1.130358  1.072400
# 2005-12-31             0.850467              1.310200  1.080200
# 2006-12-31                  NaN                   NaN       NaN
# 2007-12-31                  NaN                   NaN       NaN
# 2008-12-31             1.008356              1.020378  1.014356
# 2009-12-31                  NaN                   NaN       NaN
# 2010-12-31             0.973800              0.832700  0.903400
# 2011-12-31             1.099400              1.079867  1.089533
# 2012-12-31                  NaN                   NaN       NaN
# 2013-12-31                  NaN                   NaN       NaN
# 2014-12-31                  NaN                   NaN       NaN
# 2015-12-31                  NaN                   NaN       NaN
# 2016-12-31             0.874600              0.851400  0.863000
# 2017-12-31             0.809500              0.698800  0.754100
# 2018-12-31                  NaN                   NaN       NaN
# 2019-12-31             0.844867              0.752933  0.798867

# %%
plt.plot(iri_df2)
plt.legend(iri_df2)

# %%
climate_df2.to_excel('Climate Yearly sampled.xlsx')
iri_df2.to_excel('IRI Yearly sampled.xlsx')

# %%
# df1.plot(x="YEAR", y="YEARLY",kind = 'area', figsize=(19,10))
# plt.title("Yearly Intense precipitation of a region of Chattanooga - Rolling Mean")
# plt.xlabel('Years')
# plt.ylabel('Precipitation')
# plt.savefig("Intense precipitation", dpi=100)
# plt.show()

climate_df2.plot(y=['INTENSE_PRECIP_DAYS_MONTH'], use_index=True)
# fig,ax=plt.subplots()
# Out:
# <AxesSubplot:xlabel='timedate'>

# %%
# climate_df3 = climate_df2['INTENSE_PRECIP_DAYS_MONTH']
# analysis1 = [iri_df2,climate_df3]
# res_analysis1 = pd.concat(analysis1)

iri_df2['Intense_precipitation'] = climate_df2['INTENSE_PRECIP_DAYS_MONTH']
# iri_df2['Total_Precipitation'] = climate_df2['TOTAL_MON_PRECIP']
# res_analysis1

plt.figure(figsize=(19,10))
plt.plot(iri_df2)
plt.legend(iri_df2)
plt.title("Intense_Precip and IRI values")
plt.xlabel('Years')
plt.ylabel('Precip in days | IRI measure')
plt.savefig("raw intense precip and IRI", dpi=100)

# %%
climate_df2.to_excel('Climate Yearly sampled.xlsx')
iri_df2.to_excel('IRI Yearly sampled.xlsx')

# %%
# Finding Correlation Using Pearson Co-relation method
iri_df2_corr = iri_df2.corr()
iri_df2_corr2 = iri_df2_corr.style.background_gradient(cmap='Spectral')
iri_df2_corr2
# iri_df2_corr.to_excel('Correlation between IRI and Intense Precip')
# Out:
# <style  type="text/css" >
# #T_a3b83_row0_col0,#T_a3b83_row1_col1,#T_a3b83_row2_col2,#T_a3b83_row3_col3{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }#T_a3b83_row0_col1{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_a3b83_row0_col2{
#             background-color:  #62bda7;
#             color:  #000000;
#         }#T_a3b83_row0_col3,#T_a3b83_row3_col0,#T_a3b83_row3_col1,#T_a3b83_row3_col2{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_a3b83_row1_col0{
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_a3b83_row1_col2{
#             background-color:  #49a2b2;
#             color:  #000000;
#         }#T_a3b83_row1_col3{
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_a3b83_row2_col0,#T_a3b83_row2_col1{
#             background-color:  #52abae;
#             color:  #000000;
#         }#T_a3b83_row2_col3{
#             background-color:  #e85b48;
#             color:  #000000;
#         }</style><table id="T_a3b83_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >IRI_LEFT_WHEEL_PATH</th>        <th class="col_heading level0 col1" >IRI_RIGHT_WHEEL_PATH</th>        <th class="col_heading level0 col2" >MRI</th>        <th class="col_heading level0 col3" >Intense_precipitation</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3b83_level0_row0" class="row_heading level0 row0" >IRI_LEFT_WHEEL_PATH</th>
#                         <td id="T_a3b83_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a3b83_row0_col1" class="data row0 col1" >0.528142</td>
#                         <td id="T_a3b83_row0_col2" class="data row0 col2" >0.856803</td>
#                         <td id="T_a3b83_row0_col3" class="data row0 col3" >0.110150</td>
#             </tr>
#             <tr>
#                         <th id="T_a3b83_level0_row1" class="row_heading level0 row1" >IRI_RIGHT_WHEEL_PATH</th>
#                         <td id="T_a3b83_row1_col0" class="data row1 col0" >0.528142</td>
#                         <td id="T_a3b83_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_a3b83_row1_col2" class="data row1 col2" >0.890376</td>
#                         <td id="T_a3b83_row1_col3" class="data row1 col3" >0.317326</td>
#             </tr>
#             <tr>
#                         <th id="T_a3b83_level0_row2" class="row_heading level0 row2" >MRI</th>
#                         <td id="T_a3b83_row2_col0" class="data row2 col0" >0.856803</td>
#                         <td id="T_a3b83_row2_col1" class="data row2 col1" >0.890376</td>
#                         <td id="T_a3b83_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_a3b83_row2_col3" class="data row2 col3" >0.253233</td>
#             </tr>
#             <tr>
#                         <th id="T_a3b83_level0_row3" class="row_heading level0 row3" >Intense_precipitation</th>
#                         <td id="T_a3b83_row3_col0" class="data row3 col0" >0.110150</td>
#                         <td id="T_a3b83_row3_col1" class="data row3 col1" >0.317326</td>
#                         <td id="T_a3b83_row3_col2" class="data row3 col2" >0.253233</td>
#                         <td id="T_a3b83_row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# Compiling but Not working functions 

# def columns_plot(df1, df2, x_ax, y_ax):
#     columns = (df1[x_ax], df2[y_ax])
#     to_plot_df = pd.concat(columns,ignore_index=True)
#     #plot = plt.plot(to_plot_df)
#     return to_plot_df
